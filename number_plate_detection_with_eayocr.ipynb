# %%
# !git config --global user.name "ss9180"
# !git config --global user.email "ss9180@srmist.edu.in"
# !git config --global credential.helper store

# %%
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()

hf_token = user_secrets.get_secret("hf")
login(token = hf_token)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
import os
from huggingface_hub import hf_hub_download

repo_id = "infinitymatter/license"  # replace with the ID of the repo you want to clone
repo_dir = "/kaggle/working"  # replace with the local directory where you want to clone the repo

hf_hub_download(repo_id, repo_dir, use_auth_token=True)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/conda/lib/python3.10/site-packages/huggingface_hub/utils/_errors.py:304, in hf_raise_for_status(response, endpoint_name)
#     303 try:
# --> 304     response.raise_for_status()
#     305 except HTTPError as e:
#
# File /opt/conda/lib/python3.10/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/infinitymatter/license/resolve/main//kaggle/working
#
# The above exception was the direct cause of the following exception:
#
# EntryNotFoundError                        Traceback (most recent call last)
# Cell In[3], line 7
#       4 repo_id = "infinitymatter/license"  # replace with the ID of the repo you want to clone
# ...

# %%
from huggingface_hub import hf_hub_download

# %%
from huggingface_hub import HfApi

# Replace with your token
api = HfApi()
token = "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"

# Replace with your private repo ID (e.g., "username/repo_name")
repo_id = "infinitymatter/license"

# List files in the repo
files = api.list_repo_files(repo_id=repo_id, token=token)

# Download each file
for file_name in files:
    hf_hub_download(repo_id=repo_id, filename=file_name, token=token, local_dir="./")
# Out:
# .gitattributes:   0%|          | 0.00/1.52k [00:00<?, ?B/s]
# .gitignore:   0%|          | 0.00/3.24k [00:00<?, ?B/s]
# LICENSE:   0%|          | 0.00/1.10k [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/1.67k [00:00<?, ?B/s]
# add_missing_data.py:   0%|          | 0.00/4.56k [00:00<?, ?B/s]
# license_plate_detector.pt:   0%|          | 0.00/6.24M [00:00<?, ?B/s]
# main.py:   0%|          | 0.00/4.52k [00:00<?, ?B/s]
# requirements.txt:   0%|          | 0.00/125 [00:00<?, ?B/s]
# sort/.gitignore:   0%|          | 0.00/22.0 [00:00<?, ?B/s]
# sort/LICENSE:   0%|          | 0.00/35.1k [00:00<?, ?B/s]
# sort/README.md:   0%|          | 0.00/5.42k [00:00<?, ?B/s]
# sort/Sort.py:   0%|          | 0.00/11.7k [00:00<?, ?B/s]
# sort/data/train/ADL-Rundle-6/det/det.txt:   0%|          | 0.00/238k [00:00<?, ?B/s]
# sort/data/train/ADL-Rundle-8/det/det.txt:   0%|          | 0.00/287k [00:00<?, ?B/s]
# sort/data/train/ETH-Bahnhof/det/det.txt:   0%|          | 0.00/341k [00:00<?, ?B/s]
# ...

# %%
# !pip install -r /kaggle/working/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.9/58.9 kB 897.6 kB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 595.4/595.4 kB 5.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 47.6 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 22.9 MB/s eta 0:00:0000:0100:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 45.7 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 23.5 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 31.3 MB/s eta 0:00:00a 0:00:01
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
#   Attempting uninstall: pandas
# ...

# %%
# !python main.py
# Out:
# ...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 74.2MB/s]
# 2024-08-13 14:54:49.256
# ...
#   command:
#
#     streamlit run main.py [ARGUMENTS]
# 2024-08-13 14:54:53.398949: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-13 14:54:53.399048: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-13 14:54:53.523484: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#
# 0: 384x640 21 cars, 1 bus, 2 trucks, 94.9ms
# Speed: 3.8ms preprocess, 94.9ms inference, 205.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 license_plates, 10.4ms
# ...

# %%
# !streamlit run main.py
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Local URL: http://localhost:8501
#   Network URL: http://172.19.2.2:8501
#   External URL: http://35.202.221.127:8501
#
# ^C
#   Stopping...

# %%
import shutil

# Define the source path (adjust the path according to your dataset name)
source_path = '/kaggle/input/sample/sample.mp4'

# Define the destination path
destination_path = '/kaggle/working/sample.mp4'  # or '/kaggle/output/your-file.mp4'

# Copy the file to the desired directory
shutil.copy(source_path, destination_path)

print("File copied successfully!")
# Out:
# File copied successfully!

# %%
# !python add_missing_data.py
# Out:
# ['207', '208', '220', '221', '227', '231', '232', '233', '240', '241', '242', '243', '246', '247', '248', '251', '252', '253', '254', '255', '257', '260', '262', '263', '264', '265', '266', '270', '271', '272', '273', '274', '275', '276', '277', '278', '279', '280', '281', '282', '283', '284', '285', '286', '287', '288', '289', '290', '291', '292', '293', '294', '295', '296', '298', '299', '300', '301', '302', '303', '304', '305', '306', '307', '308', '309', '310', '311', '312', '313', '314', '315', '316', '317', '318', '319', '320', '321', '322', '324', '325', '326', '327', '328', '329', '330', '331', '334', '335', '339', '340', '341', '342', '343', '344', '345', '346', '348', '349', '350', '351', '352', '353', '354', '355', '356', '357', '358', '359', '360', '361', '362', '363', '364', '365', '366', '367', '368', '369', '370', '372', '373', '375', '377', '378', '379', '380', '381', '382', '383', '384', '385', '386', '387', '388', '389', '390', '391', '392', '393', '394', '396', '39
# ...

# %%
# !python visualize.py
